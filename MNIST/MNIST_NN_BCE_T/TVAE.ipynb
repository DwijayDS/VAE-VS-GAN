# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Libraries for Dataset
from torchvision import transforms
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

# Summary writer and path
from torch.utils.tensorboard import SummaryWriter

# Libraries for array operations
import numpy as np
import matplotlib.pyplot as plt

# Libraries for Pytorch dataset module
from torch.utils.data import Dataset, DataLoader

#Libraries for ML
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Visualization and Saving Image
import matplotlib.pyplot as plt
from torchvision.utils import save_image

import copy

# %%
# Fetching Dataset
mnist_data = fetch_openml('mnist_784', version=1)
#mist = fetch_openml('mnist_784', version=1)


# Seperating data and Target
X = np.array(mnist_data.data.astype('float32'))
y = np.array(mnist_data.target.astype('int64'))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
t = []

# %%
t.append(np.where(y_train==0)[0])

# %%
t[0]
# Out:
# array([    5,    17,    21, ..., 52490, 52498, 52499])

# %%
y_train[0]
# Out:
# 3

# %%
#copy.deepcopy(X_train[0])

# %%
class Mnist_Train_Dataset(Dataset):

  def __init__(self, noise=0,noise_mean = 0, noise_std = 0.2):

    '''
    Dataset module design for train dataset
    '''

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_train)[1]

    self.max = 255


    # Calculating positive and negative indices of every target
    self.similar_target = []
    self.negative_target = []

    for i in range(0,10):
      self.similar_target.append(np.where(y_train==i)[0])
      self.negative_target.append(np.where(y_train!=i)[0])

  def __len__(self):

    '''
    Returning number of datapoints in training
    '''

    return np.shape(X_train)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''

    # Normalization

    # Fetching anchor

    anchor_vector = copy.deepcopy(X_train[idx])/self.max

    target_vector = copy.deepcopy(X_train[idx])/self.max

    # Fetching Positive data

    while (1):

      positive_index = np.random.choice(self.similar_target[y_train[idx]],1)[0]

      if positive_index != idx:

        positive_vector = copy.deepcopy(X_train[positive_index])/self.max
        break

    # Fetching negative data
    
    negative_index = np.random.choice(self.negative_target[y_train[idx]],1)[0]

    negative_vector = copy.deepcopy(X_train[negative_index])/self.max

    # Adding Noise to the ANCHOR VECTOR



    # Changing shape of the vector

    anchor_vector = torch.squeeze(torch.from_numpy(np.reshape(anchor_vector,(1,self.size)))).float()

    positive_vector = torch.squeeze(torch.from_numpy(np.reshape(positive_vector,(1,self.size)))).float()

    negative_vector = torch.squeeze(torch.from_numpy(np.reshape(negative_vector,(1,self.size)))).float()

    target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

    sample = {'anchor_vector':anchor_vector, 'positive_vector':positive_vector, 'negative_vector':negative_vector, 'target_vector':target_vector}

    return sample

# %%
class Mnist_Validation_Dataset(Dataset):

  def __init__(self, noise=0,noise_mean = 0, noise_std = 0.2):

    '''
    Dataset module design for train dataset
    '''

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_test)[1]

    self.max = 255


    # Calculating positive and negative indices of every target
    self.similar_target = []
    self.negative_target = []

    for i in range(0,10):
      self.similar_target.append(np.where(y_test==i)[0])
      self.negative_target.append(np.where(y_test!=i)[0])

  def __len__(self):

    '''
    Returning number of datapoints in training
    '''

    return np.shape(X_test)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''

    # Normalization

    # Fetching anchor

    anchor_vector = copy.deepcopy(X_test[idx])/self.max

    target_vector = copy.deepcopy(X_test[idx])/self.max 

    # Fetching Positive data

    while (1):

      positive_index = np.random.choice(self.similar_target[y_test[idx]],1)[0]

      if positive_index != idx:

        positive_vector = copy.deepcopy(X_test[positive_index])/self.max
        break

    # Fetching negative data
    
    negative_index = np.random.choice(self.negative_target[y_test[idx]],1)[0]

    negative_vector = copy.deepcopy(X_test[negative_index])/self.max



    # Changing shape of the vector

    anchor_vector = torch.squeeze(torch.from_numpy(np.reshape(anchor_vector,(1,self.size)))).float()

    positive_vector = torch.squeeze(torch.from_numpy(np.reshape(positive_vector,(1,self.size)))).float()

    negative_vector = torch.squeeze(torch.from_numpy(np.reshape(negative_vector,(1,self.size)))).float()

    target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

    sample = {'anchor_vector':anchor_vector, 'positive_vector':positive_vector, 'negative_vector':negative_vector, 'target_vector':target_vector}

    return sample

# %%
class Mnist_Visualization(Dataset):

  def __init__(self, noise=0,noise_mean = 0, noise_std = 0.2):

    '''
    Dataset module design for train dataset
    '''

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_test)[1]

    self.max = 255


    # Calculating positive and negative indices of every target
    self.similar_target = []
    self.negative_target = []

    for i in range(0,10):
      self.similar_target.append(np.where(y_test==i)[0])
      self.negative_target.append(np.where(y_test!=i)[0])

  def __len__(self):

    '''
    Returning number of datapoints in training
    '''

    return np.shape(X_test)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''
    sample = {}

    for i in range(0,10):

      # Normalization

      # Fetching anchor

      anchor_vector = copy.deepcopy(X_test[np.random.choice(self.similar_target[i],1)[0]])/self.max

      target_vector = copy.deepcopy(anchor_vector)

      # Fetching Positive data


      positive_vector = copy.deepcopy(X_test[np.random.choice(self.similar_target[i],1)[0]])/self.max
      

      # Fetching negative data
      
      negative_index = np.random.choice(self.negative_target[y_test[idx]],1)[0]

      negative_vector = copy.deepcopy(X_test[negative_index])/self.max



      # Changing shape of the vector

      anchor_vector = torch.squeeze(torch.from_numpy(np.reshape(anchor_vector,(1,self.size)))).float()

      positive_vector = torch.squeeze(torch.from_numpy(np.reshape(positive_vector,(1,self.size)))).float()

      negative_vector = torch.squeeze(torch.from_numpy(np.reshape(negative_vector,(1,self.size)))).float()

      target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

      s = {'anchor_vector':anchor_vector, 'positive_vector':positive_vector, 'negative_vector':negative_vector, 'target_vector':target_vector}

      sample[i] = s
    return sample

# %%
# mnist_vis = Mnist_Visualization()
# mnist_vis[0]

# %%
class VAE(nn.Module):

  def __init__(self,latent_dimentions=2, p=0.2):

    super(VAE,self).__init__()

    '''
    Lets define encoder parameters.
    '''

    en_inp_dim = 28*28

    en_hid1 = 500

    en_hid2 = 300

    en_hid3 = 200

    en_out = latent_dimentions

    self.encoder1 = nn.Linear(en_inp_dim,en_hid1)

    self.en_drop1 = nn.Dropout(p=p)

    self.encoder2 = nn.Linear(en_hid1,en_hid2)

    self.en_drop2 = nn.Dropout(p=p)

    self.encoder3 = nn.Linear(en_hid2,en_hid3)

    self.en_drop3 = nn.Dropout(p=p)

    self.mean_layer = nn.Linear(en_hid3,en_out)

    self.log_var_layer = nn.Linear(en_hid3,en_out)


    '''
    Defining parameters for decoder
    '''

    dec_inp_dim = latent_dimentions

    dec_hid1 = 200

    dec_hid2 = 300

    dec_hid3 = 500

    dec_out = 28*28

    self.decoder1 = nn.Linear(dec_inp_dim,dec_hid1)

    self.dec_drop1 = nn.Dropout(p=p)

    self.decoder2 = nn.Linear(dec_hid1,dec_hid2)

    self.dec_drop2 = nn.Dropout(p=p)

    self.decoder3 = nn.Linear(dec_hid2,dec_hid3)

    self.dec_drop3 = nn.Dropout(p=p)

    self.decoder_out_layer = nn.Linear(dec_hid3,dec_out)



  def Encoder(self,x):

    '''
    Defining Dncoder Layer
    '''

    x = F.relu(self.encoder1(x))

    x = self.en_drop1(x)

    x = F.relu(self.encoder2(x))

    x = self.en_drop2(x)

    x = F.relu(self.encoder3(x))

    x = self.en_drop3(x)

    mean = self.mean_layer(x)   

    log_var = self.log_var_layer(x)

    return mean,log_var

  def Decoder(self,z):

    '''
    Defining Decoder Layer
    '''

    x = F.relu(self.decoder1(z))

    x = self.dec_drop1(x)

    x = F.relu(self.decoder2(x))

    x = self.dec_drop2(x)

    x = F.relu(self.decoder3(x))

    x = self.dec_drop3(x)

    x = F.sigmoid(self.decoder_out_layer(x))

    return x

  def Sample(self,mean,log_var):

    '''
    Sampling from gaussian ditribution using reparameterization technique
    '''
    #Satandard Deviation
    std = torch.exp(0.5*log_var)
    #Gaussian sample with Standard deviation std
    eps = torch.randn_like(std)
    # Gaussian sample with Standard deviation std and Mean mean
    return eps.mul(std).add_(mean)

  def forward(self, x):
    '''
    Forward pass through VAE
    '''
    # Extracting mean and variance from encoder
    mu, log_var = self.Encoder(x)
    # Fetching sample from distribution
    z = self.Sample(mu, log_var)
    
    # Return decoded signal with mean and log variance generated
    return (self.Decoder(z), mu, log_var)

# %%
def Euclidean_Distance(x1, x2):
  # Calculating Euclidean DIstance between x1 and x2
  return (x1 - x2).pow(2).sum(1)

def Triplet_loss(anchor,positive,negative):
  # Triplet loss
  Positive_distance = Euclidean_Distance(anchor, positive)
  Negative_distance = Euclidean_Distance(anchor, negative)
  loss = torch.relu(Positive_distance - Negative_distance + 1.0)
  
  return torch.sum(loss)

# %%
def Negative_ELBO_BCE_KL(pred, target, mean, log_var, batch_size, anchor, positive, negative):
  '''
  Function that compute ELBO and negates it so that we can convert maximization task to minimization task
  '''

  # Calculating Binary Cross Entropy
  # This part is to check reconstruction of target image
  BCE = F.binary_cross_entropy(pred, target, reduction='sum') 
  #print(BCE)

  # Calculating KL Divergence
  # This Calculates how good is mean and variance
  KL = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
  #print(KL)
  #KL = KL / batch_size

  T_loss = (Triplet_loss(anchor,positive,negative))


  return (BCE + KL + T_loss) / batch_size

# %%
#Setting up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Reading data loader and dataset class
train_data = Mnist_Train_Dataset()
train_dataloader = DataLoader(train_data,batch_size=128,shuffle=True)

# Reading data loader and dataset class
validation_data = Mnist_Validation_Dataset()
validation_dataloader = DataLoader(validation_data,batch_size=128,shuffle=True)

# Visualization
mnist_vis = Mnist_Visualization()

# Defining VAE Model 
net = VAE(latent_dimentions=20).to(device)

# Defining loss function
criterion = nn.CrossEntropyLoss()

#Optimizer selection
#optimizer = optim.SGD(net.parameters(),lr = 0.0001)
optimizer = optim.Adam(net.parameters())

# %%
#train_data[0]

# %%
# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('/content/drive/My Drive/Colab Notebooks/VAE/MNIST_NN_BCE_T/savings/LD20/')

# %%
for epoch in range(201):

  running_loss = 0
  running_acc = 0
  count = 0

  for i,data in enumerate(train_dataloader):
    net.train()
    # get the inputs; data is a list of [inputs, labels]
    #sample = {'anchor_vector':anchor_vector, 'positive_vector':positive_vector, 'negative_vector':negative_vector, 'target_vector':target_vector}

    anchor_inp, positive_inp = data['anchor_vector'].to(device), data['positive_vector'].to(device)

    negative_inp, labels = data['negative_vector'].to(device), data['target_vector'].to(device)

    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    # Main output
    outputs = net(anchor_inp)
    # anchor mean
    anchor = outputs[1]
    # Positive mean
    positive = net(positive_inp)[1]
    # Negative mean
    negative = net(negative_inp)[1]

    #Calculating Accuracy
    #accuracy = torch.sum(torch.argmax(outputs,dim=1) == labels).float()/np.shape(labels)[0]
    #print(outputs.size())

    #Calculating Loss
    loss = Negative_ELBO_BCE_KL(pred=outputs[0], target=labels, mean=outputs[1], log_var=outputs[2], batch_size=np.shape(labels)[0], anchor=anchor, positive=positive, negative=negative) 
    loss.backward()
    optimizer.step()

    

    # print statistics
    running_loss += loss.item()
    #running_acc  += accuracy.item()
    count += 1
    if i % 100 == 0:    # print every 100 mini-batches
      #After one training loop
      print('------------------------------------------------------------------------------------------------------')
      print('Epoch:',epoch+1)
      print('Iteration: %d Average Training Loss: %.3f' % (i, running_loss / count))
      writer.add_scalar('Average Training Loss : ',running_loss / count,epoch * len(train_dataloader) + i)
      
      running_loss = 0.0
      
      count = 0
      val_loss = 0
      val_acc = 0
      val_count = 0
      net.eval()
      with torch.no_grad():
        for val_i,val_data in enumerate(validation_dataloader):
          anchor_inp, positive_inp = val_data['anchor_vector'].to(device), val_data['positive_vector'].to(device)

          negative_inp, val_labels = val_data['negative_vector'].to(device), val_data['target_vector'].to(device)
          # Main output
          val_outputs = net(anchor_inp)
          # anchor mean
          anchor = val_outputs[1]
          # Positive mean
          positive = net(positive_inp)[1]
          # Negative mean
          negative = net(negative_inp)[1]

          #Calculating Accuracy
          #accuracy = torch.sum(torch.argmax(outputs,dim=1) == labels).float()/np.shape(labels)[0]
          #print(outputs.size())

          #Calculating Loss
          val_loss += Negative_ELBO_BCE_KL(pred=val_outputs[0], target=val_labels, mean=val_outputs[1], log_var=val_outputs[2], batch_size=np.shape(val_labels)[0], anchor=anchor, positive=positive, negative=negative).item()
          
          val_count += 1
          #if val_i%10000 == 0:
          #  break
          
      print('Average Validation Loss:',val_loss/val_count)
      writer.add_scalar('Average Validation Loss',val_loss / val_count,epoch * len(train_dataloader) + i)
      
  if epoch % 50 == 0:


    temp_full = mnist_vis[0]

    for key,val in temp_full.items():

      out = net(val['anchor_vector'].to(device))

      save_image(out[0].data.view(28, 28),'/content/drive/My Drive/Colab Notebooks/VAE/MNIST_NN_BCE_T/savings/LD20/' + str(epoch)+'/'+str(key)+'_pred' + '.png')
      save_image(val['target_vector'].view(28,28),'/content/drive/My Drive/Colab Notebooks/VAE/MNIST_NN_BCE_T/savings/LD20/' + str(epoch)+'/'+str(key)+'.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 0 Average Training Loss: 544.277
# Average Validation Loss: 535.6910168724338
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 100 Average Training Loss: 228.625
# Average Validation Loss: 201.52909973590045
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 200 Average Training Loss: 199.506
# Average Validation Loss: 192.70166338621266
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 300 Average Training Loss: 190.366
# Average Validation Loss: 181.41122358558823
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 400 Average Training Loss: 182.421
# Average Validation Loss: 173.96524304021014
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 0 Average Training Loss: 174.555
# Average Validation Loss: 173.34872837484318
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 100 Average Training Loss: 175.045
# Average Validation Loss: 165.50026764138772
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 200 Average Training Loss: 167.312
# Average Validation Loss: 157.18090876001511
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 300 Average Training Loss: 161.105
# Average Validation Loss: 152.22382972884353
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 400 Average Training Loss: 157.510
# Average Validation Loss: 148.5939110526203
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 0 Average Training Loss: 151.543
# Average Validation Loss: 148.79880440148125
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 100 Average Training Loss: 154.743
# Average Validation Loss: 144.85210591337108
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 200 Average Training Loss: 151.035
# Average Validation Loss: 142.40512307716983
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 300 Average Training Loss: 149.908
# Average Validation Loss: 141.0854726081347
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 400 Average Training Loss: 148.496
# Average Validation Loss: 140.1555095589074
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 0 Average Training Loss: 146.693
# Average Validation Loss: 140.61477772510835
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 100 Average Training Loss: 147.082
# Average Validation Loss: 138.43154740159528
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 200 Average Training Loss: 146.189
# Average Validation Loss: 137.36943889534388
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 300 Average Training Loss: 145.447
# Average Validation Loss: 136.38884211630716
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 400 Average Training Loss: 144.317
# Average Validation Loss: 136.6056112024906
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 0 Average Training Loss: 147.078
# Average Validation Loss: 136.6065610342652
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 100 Average Training Loss: 144.035
# Average Validation Loss: 134.87966389899705
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 200 Average Training Loss: 143.073
# Average Validation Loss: 135.33282665614664
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 300 Average Training Loss: 142.356
# Average Validation Loss: 133.98013389197578
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 400 Average Training Loss: 141.888
# Average Validation Loss: 132.8701082215692
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 0 Average Training Loss: 140.826
# Average Validation Loss: 133.229895710075
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 100 Average Training Loss: 141.340
# Average Validation Loss: 132.2030133435326
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 200 Average Training Loss: 140.581
# Average Validation Loss: 131.4942582401916
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 300 Average Training Loss: 139.698
# Average Validation Loss: 130.9481042458193
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 400 Average Training Loss: 138.977
# Average Validation Loss: 130.4720080299099
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 0 Average Training Loss: 142.120
# Average Validation Loss: 131.17006655505105
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 100 Average Training Loss: 139.223
# Average Validation Loss: 130.27961948144176
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 200 Average Training Loss: 138.318
# Average Validation Loss: 130.1095801583172
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 300 Average Training Loss: 138.203
# Average Validation Loss: 129.51525845492844
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 400 Average Training Loss: 137.636
# Average Validation Loss: 129.05854802932183
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 0 Average Training Loss: 137.924
# Average Validation Loss: 129.09456044217967
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 100 Average Training Loss: 136.783
# Average Validation Loss: 128.79428674182753
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 200 Average Training Loss: 136.994
# Average Validation Loss: 128.69701992508269
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 300 Average Training Loss: 136.956
# Average Validation Loss: 128.01696743930344
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 400 Average Training Loss: 137.272
# Average Validation Loss: 128.02588714822366
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 0 Average Training Loss: 137.847
# Average Validation Loss: 128.14150076538976
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 100 Average Training Loss: 137.070
# Average Validation Loss: 127.75279636800724
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 200 Average Training Loss: 136.045
# Average Validation Loss: 127.62014247031108
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 300 Average Training Loss: 136.279
# Average Validation Loss: 126.85711931660228
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 400 Average Training Loss: 134.945
# Average Validation Loss: 126.81191498693758
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 0 Average Training Loss: 133.185
# Average Validation Loss: 127.47206405305515
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 100 Average Training Loss: 136.077
# Average Validation Loss: 126.6181904590913
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 200 Average Training Loss: 135.220
# Average Validation Loss: 126.78916875463332
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 300 Average Training Loss: 135.364
# Average Validation Loss: 126.30662982133182
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 400 Average Training Loss: 134.922
# Average Validation Loss: 126.15360621988339
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 0 Average Training Loss: 133.554
# Average Validation Loss: 126.51962040810689
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 100 Average Training Loss: 134.699
# Average Validation Loss: 126.0805051483377
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 200 Average Training Loss: 134.715
# Average Validation Loss: 126.26522910681955
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 300 Average Training Loss: 134.550
# Average Validation Loss: 125.8214689936951
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 400 Average Training Loss: 134.503
# Average Validation Loss: 125.3821473504505
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 0 Average Training Loss: 137.808
# Average Validation Loss: 125.83258763891067
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 100 Average Training Loss: 134.684
# Average Validation Loss: 125.56808928329579
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 200 Average Training Loss: 133.211
# Average Validation Loss: 125.30418802525875
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 300 Average Training Loss: 133.925
# Average Validation Loss: 125.18327877295279
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 400 Average Training Loss: 134.067
# Average Validation Loss: 125.14356888819785
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 0 Average Training Loss: 135.286
# Average Validation Loss: 125.43859272977731
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 100 Average Training Loss: 133.427
# Average Validation Loss: 124.90262464537237
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 200 Average Training Loss: 133.056
# Average Validation Loss: 124.78374108084797
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 300 Average Training Loss: 133.831
# Average Validation Loss: 125.05410616241232
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 400 Average Training Loss: 133.970
# Average Validation Loss: 124.35388100060233
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 0 Average Training Loss: 135.043
# Average Validation Loss: 124.77102900595561
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 100 Average Training Loss: 133.468
# Average Validation Loss: 124.69869944997077
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 200 Average Training Loss: 133.540
# Average Validation Loss: 124.6502615935611
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 300 Average Training Loss: 133.738
# Average Validation Loss: 124.21111030300169
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 400 Average Training Loss: 132.011
# Average Validation Loss: 124.10336253590827
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 0 Average Training Loss: 134.197
# Average Validation Loss: 124.64978612078367
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 100 Average Training Loss: 133.282
# Average Validation Loss: 124.19089580452355
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 200 Average Training Loss: 133.586
# Average Validation Loss: 123.81266417120494
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 300 Average Training Loss: 132.115
# Average Validation Loss: 123.83862070793653
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 400 Average Training Loss: 132.419
# Average Validation Loss: 124.24716242212449
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 0 Average Training Loss: 130.145
# Average Validation Loss: 124.13681163927065
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 100 Average Training Loss: 132.389
# Average Validation Loss: 123.6973518315893
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 200 Average Training Loss: 131.973
# Average Validation Loss: 123.93103690042983
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 300 Average Training Loss: 132.575
# Average Validation Loss: 123.6191122792933
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 400 Average Training Loss: 132.450
# Average Validation Loss: 123.48915217044579
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 0 Average Training Loss: 130.184
# Average Validation Loss: 124.08782903295364
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 100 Average Training Loss: 132.404
# Average Validation Loss: 123.28469748392592
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 200 Average Training Loss: 131.862
# Average Validation Loss: 123.24454559548929
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 300 Average Training Loss: 132.011
# Average Validation Loss: 123.52413344557267
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 400 Average Training Loss: 132.060
# Average Validation Loss: 123.06512846563854
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 0 Average Training Loss: 127.730
# Average Validation Loss: 123.24028984125513
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 100 Average Training Loss: 132.538
# Average Validation Loss: 122.89194360440665
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 200 Average Training Loss: 132.103
# Average Validation Loss: 123.25612612536354
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 300 Average Training Loss: 131.766
# Average Validation Loss: 123.07276727161268
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 400 Average Training Loss: 131.297
# Average Validation Loss: 122.6086470889349
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 0 Average Training Loss: 136.047
# Average Validation Loss: 122.94451675971929
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 100 Average Training Loss: 131.427
# Average Validation Loss: 123.34583744689496
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 200 Average Training Loss: 131.985
# Average Validation Loss: 122.97729419791786
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 300 Average Training Loss: 131.154
# Average Validation Loss: 122.8951335823449
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 400 Average Training Loss: 132.147
# Average Validation Loss: 122.87165314611727
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 0 Average Training Loss: 135.351
# Average Validation Loss: 122.98019553971116
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 100 Average Training Loss: 131.378
# Average Validation Loss: 122.54886783126497
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 200 Average Training Loss: 131.384
# Average Validation Loss: 123.06398661815336
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 300 Average Training Loss: 132.027
# Average Validation Loss: 122.49062375256615
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 400 Average Training Loss: 131.183
# Average Validation Loss: 122.58737683818288
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 0 Average Training Loss: 131.863
# Average Validation Loss: 122.64227261508468
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 100 Average Training Loss: 131.269
# Average Validation Loss: 122.43920720232664
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 200 Average Training Loss: 131.781
# Average Validation Loss: 122.34543637463646
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 300 Average Training Loss: 130.984
# Average Validation Loss: 122.63858204862497
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 400 Average Training Loss: 130.657
# Average Validation Loss: 122.32185742454807
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 0 Average Training Loss: 134.621
# Average Validation Loss: 122.68617499135706
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 100 Average Training Loss: 131.208
# Average Validation Loss: 122.37713439273138
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 200 Average Training Loss: 131.767
# Average Validation Loss: 122.23717888602376
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 300 Average Training Loss: 130.639
# Average Validation Loss: 122.21747466595504
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 400 Average Training Loss: 130.488
# Average Validation Loss: 121.88339818133055
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 0 Average Training Loss: 131.733
# Average Validation Loss: 122.1573351560718
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 100 Average Training Loss: 130.610
# Average Validation Loss: 122.0733527858762
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 200 Average Training Loss: 131.178
# Average Validation Loss: 122.11325050966583
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 300 Average Training Loss: 131.253
# Average Validation Loss: 121.86271996045635
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 400 Average Training Loss: 130.346
# Average Validation Loss: 121.8654865348426
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 0 Average Training Loss: 128.689
# Average Validation Loss: 121.74171096913136
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 100 Average Training Loss: 130.389
# Average Validation Loss: 121.66854708038107
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 200 Average Training Loss: 130.830
# Average Validation Loss: 121.49331431145215
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 300 Average Training Loss: 130.583
# Average Validation Loss: 121.72279240963233
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 400 Average Training Loss: 130.449
# Average Validation Loss: 121.77325149870266
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 0 Average Training Loss: 130.573
# Average Validation Loss: 121.93041312781564
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 100 Average Training Loss: 130.520
# Average Validation Loss: 121.7343072821624
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 200 Average Training Loss: 130.867
# Average Validation Loss: 121.91537776306598
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 300 Average Training Loss: 130.544
# Average Validation Loss: 121.8548663619661
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 400 Average Training Loss: 130.245
# Average Validation Loss: 121.59990692138672
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 0 Average Training Loss: 130.730
# Average Validation Loss: 121.8951072414426
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 100 Average Training Loss: 130.362
# Average Validation Loss: 122.0310477375114
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 200 Average Training Loss: 130.208
# Average Validation Loss: 121.56791904198862
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 300 Average Training Loss: 130.500
# Average Validation Loss: 121.8814488431833
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 400 Average Training Loss: 130.223
# Average Validation Loss: 121.31733425168225
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 0 Average Training Loss: 129.492
# Average Validation Loss: 121.75857449273994
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 100 Average Training Loss: 129.540
# Average Validation Loss: 121.26083173542997
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 200 Average Training Loss: 131.082
# Average Validation Loss: 121.78226571187486
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 300 Average Training Loss: 130.239
# Average Validation Loss: 121.42840492638358
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 400 Average Training Loss: 129.825
# Average Validation Loss: 121.21526737630802
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 0 Average Training Loss: 132.039
# Average Validation Loss: 121.56935526158688
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 100 Average Training Loss: 129.725
# Average Validation Loss: 121.28415206575046
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 200 Average Training Loss: 129.948
# Average Validation Loss: 121.29758631573976
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 300 Average Training Loss: 130.003
# Average Validation Loss: 121.14311758445128
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 400 Average Training Loss: 130.700
# Average Validation Loss: 121.15551930448434
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 0 Average Training Loss: 126.712
# Average Validation Loss: 121.37677219140268
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 100 Average Training Loss: 129.471
# Average Validation Loss: 121.33700594936845
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 200 Average Training Loss: 129.875
# Average Validation Loss: 121.36533589606738
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 300 Average Training Loss: 130.028
# Average Validation Loss: 121.16716443361157
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 400 Average Training Loss: 129.897
# Average Validation Loss: 121.28675753182739
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 0 Average Training Loss: 128.225
# Average Validation Loss: 121.64450507616475
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 100 Average Training Loss: 129.416
# Average Validation Loss: 121.14945499392321
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 200 Average Training Loss: 129.556
# Average Validation Loss: 120.87389067489735
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 300 Average Training Loss: 129.901
# Average Validation Loss: 120.88263268018291
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 400 Average Training Loss: 130.334
# Average Validation Loss: 120.91151528462876
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 0 Average Training Loss: 127.052
# Average Validation Loss: 121.04862697629163
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 100 Average Training Loss: 130.172
# Average Validation Loss: 120.71661282281806
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 200 Average Training Loss: 129.295
# Average Validation Loss: 120.9905951284144
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 300 Average Training Loss: 129.331
# Average Validation Loss: 120.80083253957929
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 400 Average Training Loss: 129.241
# Average Validation Loss: 120.64722308973326
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 0 Average Training Loss: 129.634
# Average Validation Loss: 120.96269337452242
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 100 Average Training Loss: 129.556
# Average Validation Loss: 120.97407080657291
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 200 Average Training Loss: 129.510
# Average Validation Loss: 121.09996377986712
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 300 Average Training Loss: 129.744
# Average Validation Loss: 120.87127345843906
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 400 Average Training Loss: 129.744
# Average Validation Loss: 120.7133728918368
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 0 Average Training Loss: 130.064
# Average Validation Loss: 121.27165907142806
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 100 Average Training Loss: 129.545
# Average Validation Loss: 120.79003599960438
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 200 Average Training Loss: 129.585
# Average Validation Loss: 120.37501503603302
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 300 Average Training Loss: 129.438
# Average Validation Loss: 120.75964260797431
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 400 Average Training Loss: 129.414
# Average Validation Loss: 120.71983643691905
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 0 Average Training Loss: 130.659
# Average Validation Loss: 120.86359143779225
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 100 Average Training Loss: 128.659
# Average Validation Loss: 120.62591886868442
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 200 Average Training Loss: 129.449
# Average Validation Loss: 120.56419461661011
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 300 Average Training Loss: 129.487
# Average Validation Loss: 120.50012179186744
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 400 Average Training Loss: 129.529
# Average Validation Loss: 120.61650859526475
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 0 Average Training Loss: 133.062
# Average Validation Loss: 120.57397828484974
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 100 Average Training Loss: 129.206
# Average Validation Loss: 120.50783316062315
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 200 Average Training Loss: 129.004
# Average Validation Loss: 120.46364376318716
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 300 Average Training Loss: 129.650
# Average Validation Loss: 120.66138608612283
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 400 Average Training Loss: 129.294
# Average Validation Loss: 120.43687650583087
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 0 Average Training Loss: 126.519
# Average Validation Loss: 120.67966566990762
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 100 Average Training Loss: 129.745
# Average Validation Loss: 120.59073533106894
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 200 Average Training Loss: 128.438
# Average Validation Loss: 120.58592496997248
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 300 Average Training Loss: 128.937
# Average Validation Loss: 120.17851853196639
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 400 Average Training Loss: 129.548
# Average Validation Loss: 120.62087043706518
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 0 Average Training Loss: 129.582
# Average Validation Loss: 120.74938096095175
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 100 Average Training Loss: 129.165
# Average Validation Loss: 120.48400650581304
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 200 Average Training Loss: 128.285
# Average Validation Loss: 120.40919327561873
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 300 Average Training Loss: 129.197
# Average Validation Loss: 120.25577845886676
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 400 Average Training Loss: 129.192
# Average Validation Loss: 120.23214042273752
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 0 Average Training Loss: 133.060
# Average Validation Loss: 120.62000541965456
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 100 Average Training Loss: 128.791
# Average Validation Loss: 120.21683034409571
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 200 Average Training Loss: 129.568
# Average Validation Loss: 120.26183424900918
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 300 Average Training Loss: 129.109
# Average Validation Loss: 120.2681207587249
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 400 Average Training Loss: 128.724
# Average Validation Loss: 120.2641895600479
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 0 Average Training Loss: 129.982
# Average Validation Loss: 120.18261134015383
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 100 Average Training Loss: 129.060
# Average Validation Loss: 119.85289647457374
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 200 Average Training Loss: 128.312
# Average Validation Loss: 120.41221239967068
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 300 Average Training Loss: 129.453
# Average Validation Loss: 120.16343972978801
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 400 Average Training Loss: 128.708
# Average Validation Loss: 120.00260262593736
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 0 Average Training Loss: 129.302
# Average Validation Loss: 120.22565933561673
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 100 Average Training Loss: 128.411
# Average Validation Loss: 119.93630625035641
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 200 Average Training Loss: 129.300
# Average Validation Loss: 120.3485097397853
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 300 Average Training Loss: 128.974
# Average Validation Loss: 120.30765371949133
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 400 Average Training Loss: 128.843
# Average Validation Loss: 120.22644649978972
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 0 Average Training Loss: 121.592
# Average Validation Loss: 120.13845546750257
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 100 Average Training Loss: 129.264
# Average Validation Loss: 120.08583959871835
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 200 Average Training Loss: 128.428
# Average Validation Loss: 119.754648640208
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 300 Average Training Loss: 128.418
# Average Validation Loss: 120.11516170084042
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 400 Average Training Loss: 128.850
# Average Validation Loss: 119.92480574559121
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 0 Average Training Loss: 129.299
# Average Validation Loss: 120.08221223928632
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 100 Average Training Loss: 128.912
# Average Validation Loss: 120.13053348290659
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 200 Average Training Loss: 128.585
# Average Validation Loss: 119.8401337226812
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 300 Average Training Loss: 128.881
# Average Validation Loss: 119.85088103357023
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 400 Average Training Loss: 128.835
# Average Validation Loss: 119.74710160972428
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 0 Average Training Loss: 132.006
# Average Validation Loss: 120.05877178776873
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 100 Average Training Loss: 128.824
# Average Validation Loss: 120.1792400944842
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 200 Average Training Loss: 128.448
# Average Validation Loss: 119.82553228670663
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 300 Average Training Loss: 128.806
# Average Validation Loss: 120.10694534413136
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 400 Average Training Loss: 128.799
# Average Validation Loss: 119.74977813497946
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 0 Average Training Loss: 130.527
# Average Validation Loss: 120.38078525292612
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 100 Average Training Loss: 128.956
# Average Validation Loss: 119.58668195070142
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 200 Average Training Loss: 128.619
# Average Validation Loss: 120.08817931683394
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 300 Average Training Loss: 128.434
# Average Validation Loss: 120.0308175748282
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 400 Average Training Loss: 128.534
# Average Validation Loss: 119.83579716369184
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 0 Average Training Loss: 124.808
# Average Validation Loss: 119.99562328923358
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 100 Average Training Loss: 128.540
# Average Validation Loss: 119.97973844430743
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 200 Average Training Loss: 128.723
# Average Validation Loss: 119.57247807857765
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 300 Average Training Loss: 128.126
# Average Validation Loss: 120.01928593990577
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 400 Average Training Loss: 129.063
# Average Validation Loss: 119.40597957416172
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 0 Average Training Loss: 132.974
# Average Validation Loss: 119.82648451310875
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 100 Average Training Loss: 128.734
# Average Validation Loss: 119.78447333565593
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 200 Average Training Loss: 128.238
# Average Validation Loss: 120.08198012748774
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 300 Average Training Loss: 128.560
# Average Validation Loss: 119.86963698115662
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 400 Average Training Loss: 128.332
# Average Validation Loss: 119.57969220015255
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 0 Average Training Loss: 129.902
# Average Validation Loss: 119.82332405034643
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 100 Average Training Loss: 128.553
# Average Validation Loss: 119.71066885621008
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 200 Average Training Loss: 128.625
# Average Validation Loss: 119.53641626956689
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 300 Average Training Loss: 128.406
# Average Validation Loss: 119.6529610626889
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 400 Average Training Loss: 128.045
# Average Validation Loss: 119.5972292266623
# ------------------------------------------------------------------------------------------------------
# Epoch: 48
# Iteration: 0 Average Training Loss: 128.816
# Average Validation Loss: 119.50191230495481
# ...
# Epoch: 186
# Iteration: 100 Average Training Loss: 125.716
# Average Validation Loss: 117.3158745870103
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 200 Average Training Loss: 125.969
# Average Validation Loss: 117.45664944613937
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 300 Average Training Loss: 126.058
# Average Validation Loss: 117.33400392184292
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 400 Average Training Loss: 125.888
# Average Validation Loss: 117.43300155305515
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 0 Average Training Loss: 127.122
# Average Validation Loss: 117.27946199291814
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 100 Average Training Loss: 125.787
# Average Validation Loss: 117.48867524975408
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 200 Average Training Loss: 125.937
# Average Validation Loss: 117.33283172384665
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 300 Average Training Loss: 125.991
# Average Validation Loss: 117.36880303821424
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 400 Average Training Loss: 125.824
# Average Validation Loss: 117.43796684098069
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 0 Average Training Loss: 127.807
# Average Validation Loss: 117.56782648685204
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 100 Average Training Loss: 126.491
# Average Validation Loss: 117.50203370699917
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 200 Average Training Loss: 125.309
# Average Validation Loss: 117.26639562453667
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 300 Average Training Loss: 125.772
# Average Validation Loss: 117.16743196362127
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 400 Average Training Loss: 126.176
# Average Validation Loss: 117.39163453039461
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 0 Average Training Loss: 129.021
# Average Validation Loss: 117.96010216483235
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 100 Average Training Loss: 125.770
# Average Validation Loss: 117.66662313642293
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 200 Average Training Loss: 125.909
# Average Validation Loss: 117.4171052918817
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 300 Average Training Loss: 126.112
# Average Validation Loss: 117.60086950594491
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 400 Average Training Loss: 125.847
# Average Validation Loss: 117.5182447781528
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 0 Average Training Loss: 117.899
# Average Validation Loss: 117.3882159490655
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 100 Average Training Loss: 126.152
# Average Validation Loss: 117.48684319266438
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 200 Average Training Loss: 126.141
# Average Validation Loss: 117.24391224436516
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 300 Average Training Loss: 125.650
# Average Validation Loss: 117.48889488721416
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 400 Average Training Loss: 125.830
# Average Validation Loss: 117.52118961306384
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 0 Average Training Loss: 129.969
# Average Validation Loss: 117.7936119580791
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 100 Average Training Loss: 126.026
# Average Validation Loss: 117.51158259036767
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 200 Average Training Loss: 126.010
# Average Validation Loss: 117.52343332332416
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 300 Average Training Loss: 125.882
# Average Validation Loss: 117.26882856605697
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 400 Average Training Loss: 125.921
# Average Validation Loss: 117.46008139283117
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 0 Average Training Loss: 128.201
# Average Validation Loss: 117.54898945606539
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 100 Average Training Loss: 125.896
# Average Validation Loss: 117.30750987477546
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 200 Average Training Loss: 126.171
# Average Validation Loss: 117.33676826866873
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 300 Average Training Loss: 125.627
# Average Validation Loss: 117.14546454213831
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 400 Average Training Loss: 126.028
# Average Validation Loss: 117.49030337368485
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 0 Average Training Loss: 126.855
# Average Validation Loss: 118.13454242344321
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 100 Average Training Loss: 126.721
# Average Validation Loss: 117.33342252856623
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 200 Average Training Loss: 125.754
# Average Validation Loss: 117.19718225855027
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 300 Average Training Loss: 126.392
# Average Validation Loss: 117.69822715146698
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 400 Average Training Loss: 126.027
# Average Validation Loss: 117.4731066627224
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 0 Average Training Loss: 124.918
# Average Validation Loss: 117.2166339289533
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 100 Average Training Loss: 126.345
# Average Validation Loss: 117.37348865592567
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 200 Average Training Loss: 125.726
# Average Validation Loss: 117.1392169590414
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 300 Average Training Loss: 125.706
# Average Validation Loss: 117.38160003884866
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 400 Average Training Loss: 125.778
# Average Validation Loss: 117.31997229583072
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 0 Average Training Loss: 124.789
# Average Validation Loss: 117.2319017396356
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 100 Average Training Loss: 126.246
# Average Validation Loss: 117.48973183736314
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 200 Average Training Loss: 126.207
# Average Validation Loss: 117.44543022656963
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 300 Average Training Loss: 126.052
# Average Validation Loss: 117.37975160918967
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 400 Average Training Loss: 125.288
# Average Validation Loss: 117.27635159457687
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 0 Average Training Loss: 128.406
# Average Validation Loss: 117.32943374745167
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 100 Average Training Loss: 125.622
# Average Validation Loss: 117.1880126730369
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 200 Average Training Loss: 125.972
# Average Validation Loss: 117.45880483362797
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 300 Average Training Loss: 126.340
# Average Validation Loss: 117.37932820563769
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 400 Average Training Loss: 125.880
# Average Validation Loss: 117.3102244913143
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 0 Average Training Loss: 128.288
# Average Validation Loss: 117.52689038576001
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 100 Average Training Loss: 125.574
# Average Validation Loss: 117.30483613397084
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 200 Average Training Loss: 125.845
# Average Validation Loss: 117.25018689232151
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 300 Average Training Loss: 125.651
# Average Validation Loss: 117.26369214580006
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 400 Average Training Loss: 126.508
# Average Validation Loss: 117.42888240396542
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 0 Average Training Loss: 121.023
# Average Validation Loss: 117.34952506183708
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 100 Average Training Loss: 126.082
# Average Validation Loss: 117.4861218529026
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 200 Average Training Loss: 125.470
# Average Validation Loss: 117.03296410776403
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 300 Average Training Loss: 125.875
# Average Validation Loss: 117.2108781912031
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 400 Average Training Loss: 125.974
# Average Validation Loss: 117.16767148205834
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 0 Average Training Loss: 129.715
# Average Validation Loss: 117.26587933171405
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 100 Average Training Loss: 125.659
# Average Validation Loss: 117.47750993714716
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 200 Average Training Loss: 125.671
# Average Validation Loss: 117.1460274466633
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 300 Average Training Loss: 126.111
# Average Validation Loss: 117.35698922707216
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 400 Average Training Loss: 125.950
# Average Validation Loss: 117.2709791086016
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 0 Average Training Loss: 127.466
# Average Validation Loss: 117.50153194900847
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 100 Average Training Loss: 125.928
# Average Validation Loss: 117.19252292605212
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 200 Average Training Loss: 126.060
# Average Validation Loss: 117.4070167819949
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 300 Average Training Loss: 125.559
# Average Validation Loss: 117.27082334643733
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 400 Average Training Loss: 125.995
# Average Validation Loss: 117.5920494803547
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 0 Average Training Loss: 127.180
# Average Validation Loss: 117.67845187222001
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 100 Average Training Loss: 125.964
# Average Validation Loss: 117.35190933116161
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 200 Average Training Loss: 125.502
# Average Validation Loss: 117.52315671600564
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 300 Average Training Loss: 125.782
# Average Validation Loss: 117.89450362825046
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 400 Average Training Loss: 126.200
# Average Validation Loss: 117.16409970025947

# %%
# Closing the Writer and saving the model. Saving the model is not enough, we also need to save the model class as well
writer.close()
PATH = '/content/drive/My Drive/Colab Notebooks/VAE/MNIST_NN_BCE_T/savings/LD20/saved_model'
torch.save(net.state_dict(), PATH)

# %%
0.6949*128
