# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Libraries for Dataset
from torchvision import transforms
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

# Summary writer and path
from torch.utils.tensorboard import SummaryWriter

# Libraries for array operations
import numpy as np
import matplotlib.pyplot as plt

# Libraries for Pytorch dataset module
from torch.utils.data import Dataset, DataLoader

#Libraries for ML
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Visualization and Saving Image
import matplotlib.pyplot as plt
from torchvision.utils import save_image

# %%
# Fetching Dataset
mnist_data = fetch_openml('mnist_784')

# Seperating data and Target
X = np.array(mnist_data.data.astype('float32'))
y = np.array(mnist_data.target.astype('int64'))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4c27f7970d7e> in <module>()
#       1 # Fetching Dataset
# ----> 2 mnist_data = fetch_openml('mnist_784', cache=False)
#       3
#       4 # Seperating data and Target
#       5 X = np.array(mnist_data.data.astype('float32'))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/_openml.py in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame)
#     637                 "specify a numeric data_id or a name, not "
#     638                 "both.".format(data_id, name))
# --> 639         data_info = _get_data_info_by_name(name, version, data_home)
#     640         data_id = data_info['did']
#     641     elif data_id is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/_openml.py in _get_data_info_by_name(name, version, data_home)
#     364         error_msg = "No active dataset {} found.".format(name)
#     365         json_data = _get_json_content_from_openml_api(url, error_msg, True,
# --> 366                                                       data_home)
#     367         res = json_data['data']['dataset']
#     368         if len(res) > 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/datasets/_openml.py in _get_json_content_from_openml_api(url, error_message, raise_if_error, data_home)
#     166     # 412 error, not in except for nicer traceback
#     167     if raise_if_error:
# --> 168         raise ValueError(error_message)
#     169     return None
#     170
#
# ValueError: No active dataset mnist_784 found.

# %%
np.random.randint(100, size=1)[0]
# Out:
# 73

# %%
class Mnist_Train_Dataset(Dataset):

  def __init__(self,noise=0,noise_mean = 0, noise_std = 0.2):

    '''
    Dataset module design for train dataset
    '''

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_train)[1]

    self.max = 255

  def __len__(self):

    '''
    Returning number of datapoints in training
    '''

    return np.shape(X_train)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''

    # Normalization

    feature_vector = X_train[idx]/self.max

    target_vector = X_train[idx]/self.max

    # Adding Noise to the signal

    if np.random.uniform(1,0,1)[0] > 0.5:

      noise_signal = np.random.normal(self.noise_mean, self.noise_std, self.size)

      feature_vector += noise_signal

    # Changing shape of the vector

    feature_vector = torch.squeeze(torch.from_numpy(np.reshape(feature_vector,(1,self.size)))).float()

    target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

    sample = {'feature_vector':feature_vector, 'target_vector':target_vector}

    return sample

# %%
class Mnist_Validation_Dataset(Dataset):

  def __init__(self,noise=0,noise_mean = 0, noise_std = 0.2):

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_train)[1]

    self.max = 255

  def __len__(self):

    # Return Length of the total data points

    return np.shape(X_test)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''

    # Normalization

    feature_vector = X_test[idx]/self.max

    target_vector = X_test[idx]/self.max

    # Adding Noise to the signal

    if np.random.uniform(1,0,1)[0] > 0.5:

      noise_signal = np.random.normal(self.noise_mean, self.noise_std, self.size)

      feature_vector += noise_signal

    # Changing shape of the vector
    
    feature_vector = torch.squeeze(torch.from_numpy(np.reshape(feature_vector,(1,self.size)))).float()

    target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

    sample = {'feature_vector':feature_vector, 'target_vector':target_vector}

    return sample

# %%
class Mnist_Visualize(Dataset):

  def __init__(self,noise=0,noise_mean = 0, noise_std = 0.2):

    self.noise = noise

    self.noise_mean = noise_mean

    self.noise_std = noise_std

    self.size = np.shape(X_train)[1]

    self.max = 255

    # Calculating positive and negative indices of every target
    self.similar_target = []

    for i in range(0,10):
      self.similar_target.append(np.where(y_test==i)[0])

  def __len__(self):

    # Return Length of the total data points

    return np.shape(X_test)[0]

  def __getitem__(self,idx):
    '''
    Return Data vector and target vector
    
    Feature Vector : Normalized pixel values (Some noise might be added)

    Target Vector : Normalized pixel values (Without noise)
    '''
    sample = {}

    for i in range(0,10):


      # Normalization

      feature_vector = X_test[np.random.choice(self.similar_target[i],1)[0]]/self.max

      target_vector = X_test[np.random.choice(self.similar_target[i],1)[0]]/self.max

      # Adding Noise to the signal

      if np.random.uniform(1,0,1)[0] > 0.5:

        noise_signal = np.random.normal(self.noise_mean, self.noise_std, self.size)

        feature_vector += noise_signal

      # Changing shape of the vector
      
      feature_vector = torch.squeeze(torch.from_numpy(np.reshape(feature_vector,(1,self.size)))).float()

      target_vector = torch.squeeze(torch.from_numpy(np.reshape(target_vector,(1,self.size)))).float()

      s = {'feature_vector':feature_vector, 'target_vector':target_vector}

      sample[i] = s

    return sample

# %%
class VAE(nn.Module):

  def __init__(self,latent_dimentions=2, p=0.2):

    super(VAE,self).__init__()

    '''
    Lets define encoder parameters.
    '''

    en_inp_dim = 28*28

    en_hid1 = 500

    en_hid2 = 300

    en_hid3 = 200

    en_out = latent_dimentions

    self.encoder1 = nn.Linear(en_inp_dim,en_hid1)

    self.en_drop1 = nn.Dropout(p=p)

    self.encoder2 = nn.Linear(en_hid1,en_hid2)

    self.en_drop2 = nn.Dropout(p=p)

    self.encoder3 = nn.Linear(en_hid2,en_hid3)

    self.en_drop3 = nn.Dropout(p=p)

    self.mean_layer = nn.Linear(en_hid3,en_out)

    self.log_var_layer = nn.Linear(en_hid3,en_out)


    '''
    Defining parameters for decoder
    '''

    dec_inp_dim = latent_dimentions

    dec_hid1 = 200

    dec_hid2 = 300

    dec_hid3 = 500

    dec_out = 28*28

    self.decoder1 = nn.Linear(dec_inp_dim,dec_hid1)

    self.dec_drop1 = nn.Dropout(p=p)

    self.decoder2 = nn.Linear(dec_hid1,dec_hid2)

    self.dec_drop2 = nn.Dropout(p=p)

    self.decoder3 = nn.Linear(dec_hid2,dec_hid3)

    self.dec_drop3 = nn.Dropout(p=p)

    self.decoder_out_layer = nn.Linear(dec_hid3,dec_out)



  def Encoder(self,x):

    '''
    Defining Dncoder Layer
    '''

    x = F.relu(self.encoder1(x))

    x = self.en_drop1(x)

    x = F.relu(self.encoder2(x))

    x = self.en_drop2(x)

    x = F.relu(self.encoder3(x))

    x = self.en_drop3(x)

    mean = self.mean_layer(x)   

    log_var = self.log_var_layer(x)

    return mean,log_var

  def Decoder(self,z):

    '''
    Defining Decoder Layer
    '''

    x = F.relu(self.decoder1(z))

    x = self.dec_drop1(x)

    x = F.relu(self.decoder2(x))

    x = self.dec_drop2(x)

    x = F.relu(self.decoder3(x))

    x = self.dec_drop3(x)

    x = F.sigmoid(self.decoder_out_layer(x))

    return x

  def Sample(self,mean,log_var):

    '''
    Sampling from gaussian ditribution using reparameterization technique
    '''
    #Satandard Deviation
    std = torch.exp(0.5*log_var)
    #Gaussian sample with Standard deviation std
    eps = torch.randn_like(std)
    # Gaussian sample with Standard deviation std and Mean mean
    return eps.mul(std).add_(mean)

  def forward(self, x):
    '''
    Forward pass through VAE
    '''
    # Extracting mean and variance from encoder
    mu, log_var = self.Encoder(x)
    # Fetching sample from distribution
    z = self.Sample(mu, log_var)
    # Return decoded signal with mean and log variance generated
    return (self.Decoder(z), mu, log_var)

# %%
def Negative_ELBO_BCE_KL(pred, target, mean, log_var, batch_size):
  '''
  Function that compute ELBO and negates it so that we can convert maximization task to minimization task
  '''

  # Calculating Binary Cross Entropy
  # This part is to check reconstruction of target image
  BCE = F.binary_cross_entropy(pred, target, reduction='sum') 

  # Calculating KL Divergence
  # This Calculates how good is mean and variance
  KL = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())

  return (BCE + KL) / batch_size

# %%
#Setting up the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Reading data loader and dataset class
train_data = Mnist_Train_Dataset()
train_dataloader = DataLoader(train_data,batch_size=128)

# Reading data loader and dataset class
validation_data = Mnist_Validation_Dataset()
validation_dataloader = DataLoader(validation_data,batch_size=128)

# Visualizing MNIST
mnist_visualize = Mnist_Visualize()

# Defining VAE Model 
net = VAE(latent_dimentions=2).to(device)

# Defining loss function
criterion = nn.CrossEntropyLoss()

#Optimizer selection
#optimizer = optim.SGD(net.parameters(),lr = 0.0001)
optimizer = optim.Adam(net.parameters())

# %%
#mnist_visualize[0]

# %%
# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('/content/drive/My Drive/Colab Notebooks/VAE/MNIST_VAE_NN_BCE_KL/BCE_KL_NN/LD2/')

# %%
for epoch in range(201):

  running_loss = 0
  running_acc = 0
  count = 0

  for i,data in enumerate(train_dataloader):
    net.train()
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data['feature_vector'].to(device),data['target_vector'].to(device)

    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs = net(inputs)
    
    #Calculating Accuracy
    #accuracy = torch.sum(torch.argmax(outputs,dim=1) == labels).float()/np.shape(labels)[0]
    #print(outputs.size())

    #Calculating Loss
    loss = Negative_ELBO_BCE_KL(outputs[0], labels, outputs[1], outputs[2], np.shape(labels)[0]) 
    loss.backward()
    optimizer.step()

    

    # print statistics
    running_loss += loss.item()
    #running_acc  += accuracy.item()
    count += 1
    if i % 100 == 0:    # print every 100 mini-batches
      #After one training loop
      print('------------------------------------------------------------------------------------------------------')
      print('Epoch:',epoch+1)
      print('Iteration: %d Average Training Loss: %.3f' % (i, running_loss / count))
      writer.add_scalar('Average Training Loss : ',running_loss / count,epoch * len(train_dataloader) + i)
      
      running_loss = 0.0
      
      count = 0
      val_loss = 0
      val_acc = 0
      val_count = 0
      net.eval()
      with torch.no_grad():
        for val_i,val_data in enumerate(validation_dataloader):
          val_feature, val_labels = val_data['feature_vector'].to(device),val_data['target_vector'].to(device)
          val_outputs = net(val_feature)
          val_loss += Negative_ELBO_BCE_KL(val_outputs[0], val_labels, val_outputs[1], val_outputs[2], np.shape(val_labels)[0]).item()
          #val_acc += (torch.sum(torch.argmax(val_outputs,dim=1) == val_labels).float()/np.shape(val_labels)[0]).item()
          val_count += 1
          #if val_i%10000 == 0:
          #  break
          
      print('Average Validation Loss:',val_loss/val_count)
      writer.add_scalar('Average Validation Loss',val_loss / val_count,epoch * len(train_dataloader) + i)
      
  if epoch % 50 == 0:

    # Every 50 epochs we save sample images

    temp_full = mnist_visualize[0]

    for key,val in temp_full.items():

      out = net(val['feature_vector'].to(device))

      save_image(out[0].data.view(28, 28),'/content/drive/My Drive/Colab Notebooks/VAE/MNIST_VAE_NN_BCE_KL/BCE_KL_NN/LD2/' + str(epoch)+'/'+str(key)+'_pred' + '.png')
      save_image(val['target_vector'].view(28,28),'/content/drive/My Drive/Colab Notebooks/VAE/MNIST_VAE_NN_BCE_KL/BCE_KL_NN/LD2/' + str(epoch)+'/'+str(key)+'.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 0 Average Training Loss: 543.187
# Average Validation Loss: 532.6181498061131
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 100 Average Training Loss: 226.484
# Average Validation Loss: 194.44075479994726
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 200 Average Training Loss: 192.504
# Average Validation Loss: 187.81905092114079
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 300 Average Training Loss: 188.827
# Average Validation Loss: 184.2588553324233
# ------------------------------------------------------------------------------------------------------
# Epoch: 1
# Iteration: 400 Average Training Loss: 183.768
# Average Validation Loss: 175.94970769951814
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 0 Average Training Loss: 175.851
# Average Validation Loss: 175.44807445219834
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 100 Average Training Loss: 174.566
# Average Validation Loss: 167.4801528819286
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 200 Average Training Loss: 169.250
# Average Validation Loss: 162.91634864528683
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 300 Average Training Loss: 166.774
# Average Validation Loss: 160.23337872359005
# ------------------------------------------------------------------------------------------------------
# Epoch: 2
# Iteration: 400 Average Training Loss: 164.008
# Average Validation Loss: 158.68383432652828
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 0 Average Training Loss: 160.890
# Average Validation Loss: 158.8286372275248
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 100 Average Training Loss: 163.102
# Average Validation Loss: 157.75041967238823
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 200 Average Training Loss: 161.403
# Average Validation Loss: 156.62814598361942
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 300 Average Training Loss: 161.526
# Average Validation Loss: 155.44608757965756
# ------------------------------------------------------------------------------------------------------
# Epoch: 3
# Iteration: 400 Average Training Loss: 160.230
# Average Validation Loss: 154.9628402821339
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 0 Average Training Loss: 156.606
# Average Validation Loss: 154.89727794340928
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 100 Average Training Loss: 159.873
# Average Validation Loss: 154.6165398368
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 200 Average Training Loss: 158.527
# Average Validation Loss: 153.78125022275606
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 300 Average Training Loss: 159.270
# Average Validation Loss: 152.77196675321483
# ------------------------------------------------------------------------------------------------------
# Epoch: 4
# Iteration: 400 Average Training Loss: 157.944
# Average Validation Loss: 152.87531330637688
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 0 Average Training Loss: 153.705
# Average Validation Loss: 152.94731830680456
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 100 Average Training Loss: 158.174
# Average Validation Loss: 152.75988858633667
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 200 Average Training Loss: 157.022
# Average Validation Loss: 152.39654730358262
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 300 Average Training Loss: 157.536
# Average Validation Loss: 151.52002476601706
# ------------------------------------------------------------------------------------------------------
# Epoch: 5
# Iteration: 400 Average Training Loss: 156.469
# Average Validation Loss: 150.88352765828154
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 0 Average Training Loss: 151.533
# Average Validation Loss: 151.6861203604371
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 100 Average Training Loss: 156.779
# Average Validation Loss: 150.60473888981952
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 200 Average Training Loss: 155.548
# Average Validation Loss: 150.2355632921205
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 300 Average Training Loss: 156.241
# Average Validation Loss: 149.72620375139
# ------------------------------------------------------------------------------------------------------
# Epoch: 6
# Iteration: 400 Average Training Loss: 155.037
# Average Validation Loss: 149.5309505044979
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 0 Average Training Loss: 153.235
# Average Validation Loss: 150.52441194631757
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 100 Average Training Loss: 155.067
# Average Validation Loss: 148.8758648503436
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 200 Average Training Loss: 154.396
# Average Validation Loss: 148.82970211279653
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 300 Average Training Loss: 155.144
# Average Validation Loss: 149.47583163741731
# ------------------------------------------------------------------------------------------------------
# Epoch: 7
# Iteration: 400 Average Training Loss: 154.112
# Average Validation Loss: 148.54944716404825
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 0 Average Training Loss: 148.968
# Average Validation Loss: 148.84418270361684
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 100 Average Training Loss: 154.148
# Average Validation Loss: 148.4062977811716
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 200 Average Training Loss: 153.487
# Average Validation Loss: 148.59695746428775
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 300 Average Training Loss: 154.188
# Average Validation Loss: 147.89369457829608
# ------------------------------------------------------------------------------------------------------
# Epoch: 8
# Iteration: 400 Average Training Loss: 153.216
# Average Validation Loss: 147.68276253581917
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 0 Average Training Loss: 150.667
# Average Validation Loss: 147.92123546739563
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 100 Average Training Loss: 153.493
# Average Validation Loss: 147.7150236255061
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 200 Average Training Loss: 152.716
# Average Validation Loss: 147.5057463263073
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 300 Average Training Loss: 153.682
# Average Validation Loss: 147.44954519898351
# ------------------------------------------------------------------------------------------------------
# Epoch: 9
# Iteration: 400 Average Training Loss: 152.644
# Average Validation Loss: 147.37738983822564
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 0 Average Training Loss: 149.925
# Average Validation Loss: 147.49305090242927
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 100 Average Training Loss: 152.711
# Average Validation Loss: 146.96712699945826
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 200 Average Training Loss: 151.999
# Average Validation Loss: 146.6816192404197
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 300 Average Training Loss: 153.175
# Average Validation Loss: 146.98982662006017
# ------------------------------------------------------------------------------------------------------
# Epoch: 10
# Iteration: 400 Average Training Loss: 152.125
# Average Validation Loss: 146.88784188597742
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 0 Average Training Loss: 149.877
# Average Validation Loss: 146.73933132199474
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 100 Average Training Loss: 152.401
# Average Validation Loss: 146.08876984310845
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 200 Average Training Loss: 151.228
# Average Validation Loss: 146.61460275023524
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 300 Average Training Loss: 152.509
# Average Validation Loss: 146.128467754726
# ------------------------------------------------------------------------------------------------------
# Epoch: 11
# Iteration: 400 Average Training Loss: 151.562
# Average Validation Loss: 146.5438542052777
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 0 Average Training Loss: 150.107
# Average Validation Loss: 146.3706213958072
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 100 Average Training Loss: 151.284
# Average Validation Loss: 145.81197462986856
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 200 Average Training Loss: 150.961
# Average Validation Loss: 146.40456808048444
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 300 Average Training Loss: 152.062
# Average Validation Loss: 145.6804707102532
# ------------------------------------------------------------------------------------------------------
# Epoch: 12
# Iteration: 400 Average Training Loss: 150.987
# Average Validation Loss: 145.44618124857436
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 0 Average Training Loss: 149.341
# Average Validation Loss: 145.8894510756444
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 100 Average Training Loss: 150.864
# Average Validation Loss: 145.47892326856183
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 200 Average Training Loss: 150.513
# Average Validation Loss: 145.3182073439995
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 300 Average Training Loss: 151.536
# Average Validation Loss: 146.13133184057082
# ------------------------------------------------------------------------------------------------------
# Epoch: 13
# Iteration: 400 Average Training Loss: 150.943
# Average Validation Loss: 145.29627678864193
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 0 Average Training Loss: 147.874
# Average Validation Loss: 145.27706285462762
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 100 Average Training Loss: 151.039
# Average Validation Loss: 145.0720587960125
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 200 Average Training Loss: 150.152
# Average Validation Loss: 144.90427058978673
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 300 Average Training Loss: 151.031
# Average Validation Loss: 145.54003427324503
# ------------------------------------------------------------------------------------------------------
# Epoch: 14
# Iteration: 400 Average Training Loss: 150.528
# Average Validation Loss: 145.43098772703297
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 0 Average Training Loss: 149.334
# Average Validation Loss: 145.1610251099524
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 100 Average Training Loss: 150.639
# Average Validation Loss: 145.1563103668881
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 200 Average Training Loss: 149.898
# Average Validation Loss: 144.63956356744697
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 300 Average Training Loss: 150.827
# Average Validation Loss: 144.98803321114423
# ------------------------------------------------------------------------------------------------------
# Epoch: 15
# Iteration: 400 Average Training Loss: 150.199
# Average Validation Loss: 144.64060829329665
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 0 Average Training Loss: 149.085
# Average Validation Loss: 145.02279707637146
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 100 Average Training Loss: 150.263
# Average Validation Loss: 144.18543048496664
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 200 Average Training Loss: 149.491
# Average Validation Loss: 144.4211510428547
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 300 Average Training Loss: 150.533
# Average Validation Loss: 144.25216518875456
# ------------------------------------------------------------------------------------------------------
# Epoch: 16
# Iteration: 400 Average Training Loss: 149.666
# Average Validation Loss: 144.24386396199247
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 0 Average Training Loss: 146.344
# Average Validation Loss: 144.6321538103758
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 100 Average Training Loss: 150.238
# Average Validation Loss: 143.8151671695013
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 200 Average Training Loss: 149.092
# Average Validation Loss: 144.17618020607608
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 300 Average Training Loss: 150.297
# Average Validation Loss: 144.72093234097
# ------------------------------------------------------------------------------------------------------
# Epoch: 17
# Iteration: 400 Average Training Loss: 149.418
# Average Validation Loss: 143.6034712965471
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 0 Average Training Loss: 147.453
# Average Validation Loss: 144.2086332000955
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 100 Average Training Loss: 149.995
# Average Validation Loss: 144.84703910437813
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 200 Average Training Loss: 149.439
# Average Validation Loss: 144.0956517797317
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 300 Average Training Loss: 150.004
# Average Validation Loss: 143.84181759131215
# ------------------------------------------------------------------------------------------------------
# Epoch: 18
# Iteration: 400 Average Training Loss: 149.127
# Average Validation Loss: 143.80559645604043
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 0 Average Training Loss: 146.849
# Average Validation Loss: 143.63269332551607
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 100 Average Training Loss: 149.670
# Average Validation Loss: 144.05641976238167
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 200 Average Training Loss: 149.295
# Average Validation Loss: 143.44749305892165
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 300 Average Training Loss: 150.245
# Average Validation Loss: 144.07406582797532
# ------------------------------------------------------------------------------------------------------
# Epoch: 19
# Iteration: 400 Average Training Loss: 149.056
# Average Validation Loss: 143.79829974766196
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 0 Average Training Loss: 145.606
# Average Validation Loss: 143.50005502074305
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 100 Average Training Loss: 148.921
# Average Validation Loss: 143.14836432463932
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 200 Average Training Loss: 148.701
# Average Validation Loss: 143.67263270468607
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 300 Average Training Loss: 149.826
# Average Validation Loss: 143.46273748021926
# ------------------------------------------------------------------------------------------------------
# Epoch: 20
# Iteration: 400 Average Training Loss: 148.896
# Average Validation Loss: 143.63240541332829
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 0 Average Training Loss: 144.042
# Average Validation Loss: 143.42259127206177
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 100 Average Training Loss: 149.438
# Average Validation Loss: 143.6997981384723
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 200 Average Training Loss: 148.736
# Average Validation Loss: 143.72667287562015
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 300 Average Training Loss: 149.624
# Average Validation Loss: 143.7784528523466
# ------------------------------------------------------------------------------------------------------
# Epoch: 21
# Iteration: 400 Average Training Loss: 148.925
# Average Validation Loss: 143.09654202426438
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 0 Average Training Loss: 144.572
# Average Validation Loss: 143.61251853330293
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 100 Average Training Loss: 149.037
# Average Validation Loss: 143.14568078256872
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 200 Average Training Loss: 148.424
# Average Validation Loss: 143.03628005424557
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 300 Average Training Loss: 149.436
# Average Validation Loss: 143.10475403723055
# ------------------------------------------------------------------------------------------------------
# Epoch: 22
# Iteration: 400 Average Training Loss: 148.743
# Average Validation Loss: 142.8380356391851
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 0 Average Training Loss: 145.405
# Average Validation Loss: 143.27564011177006
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 100 Average Training Loss: 148.514
# Average Validation Loss: 142.86209217823335
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 200 Average Training Loss: 148.363
# Average Validation Loss: 143.36117832155995
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 300 Average Training Loss: 149.361
# Average Validation Loss: 143.34128175164662
# ------------------------------------------------------------------------------------------------------
# Epoch: 23
# Iteration: 400 Average Training Loss: 149.099
# Average Validation Loss: 142.9096305457345
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 0 Average Training Loss: 145.586
# Average Validation Loss: 143.15238351195399
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 100 Average Training Loss: 148.786
# Average Validation Loss: 142.7785728064767
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 200 Average Training Loss: 148.609
# Average Validation Loss: 143.01753591272953
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 300 Average Training Loss: 149.203
# Average Validation Loss: 142.94340559687927
# ------------------------------------------------------------------------------------------------------
# Epoch: 24
# Iteration: 400 Average Training Loss: 148.338
# Average Validation Loss: 142.69605717345746
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 0 Average Training Loss: 145.207
# Average Validation Loss: 142.8188580144061
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 100 Average Training Loss: 148.140
# Average Validation Loss: 142.38661516843922
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 200 Average Training Loss: 147.929
# Average Validation Loss: 142.67187477724394
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 300 Average Training Loss: 148.682
# Average Validation Loss: 142.68561581799582
# ------------------------------------------------------------------------------------------------------
# Epoch: 25
# Iteration: 400 Average Training Loss: 148.674
# Average Validation Loss: 142.75114162472912
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 0 Average Training Loss: 145.593
# Average Validation Loss: 142.93901540937216
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 100 Average Training Loss: 148.580
# Average Validation Loss: 143.4259047682268
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 200 Average Training Loss: 148.239
# Average Validation Loss: 142.78666664736113
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 300 Average Training Loss: 148.611
# Average Validation Loss: 142.75667198905109
# ------------------------------------------------------------------------------------------------------
# Epoch: 26
# Iteration: 400 Average Training Loss: 148.491
# Average Validation Loss: 143.59967130118042
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 0 Average Training Loss: 146.292
# Average Validation Loss: 144.014030734988
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 100 Average Training Loss: 149.078
# Average Validation Loss: 143.2441162332131
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 200 Average Training Loss: 147.787
# Average Validation Loss: 142.4283143203624
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 300 Average Training Loss: 148.693
# Average Validation Loss: 142.77479831667713
# ------------------------------------------------------------------------------------------------------
# Epoch: 27
# Iteration: 400 Average Training Loss: 147.830
# Average Validation Loss: 142.76957101195399
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 0 Average Training Loss: 144.747
# Average Validation Loss: 143.1139369324176
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 100 Average Training Loss: 148.322
# Average Validation Loss: 142.8782689449561
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 200 Average Training Loss: 147.876
# Average Validation Loss: 142.5654671105155
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 300 Average Training Loss: 148.585
# Average Validation Loss: 142.645552586465
# ------------------------------------------------------------------------------------------------------
# Epoch: 28
# Iteration: 400 Average Training Loss: 147.827
# Average Validation Loss: 142.52584504733122
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 0 Average Training Loss: 144.785
# Average Validation Loss: 142.7745200943773
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 100 Average Training Loss: 148.295
# Average Validation Loss: 142.75941801419222
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 200 Average Training Loss: 147.301
# Average Validation Loss: 142.06257751910357
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 300 Average Training Loss: 148.503
# Average Validation Loss: 142.61793473515198
# ------------------------------------------------------------------------------------------------------
# Epoch: 29
# Iteration: 400 Average Training Loss: 147.629
# Average Validation Loss: 141.98519028712363
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 0 Average Training Loss: 144.889
# Average Validation Loss: 142.36788227610344
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 100 Average Training Loss: 147.427
# Average Validation Loss: 141.873739312165
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 200 Average Training Loss: 146.893
# Average Validation Loss: 142.41793266352076
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 300 Average Training Loss: 148.162
# Average Validation Loss: 142.09436514081747
# ------------------------------------------------------------------------------------------------------
# Epoch: 30
# Iteration: 400 Average Training Loss: 147.814
# Average Validation Loss: 142.5139523248603
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 0 Average Training Loss: 144.970
# Average Validation Loss: 142.48056576025746
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 100 Average Training Loss: 147.738
# Average Validation Loss: 142.1594761757955
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 200 Average Training Loss: 146.994
# Average Validation Loss: 141.8865717310105
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 300 Average Training Loss: 148.040
# Average Validation Loss: 141.94768930699703
# ------------------------------------------------------------------------------------------------------
# Epoch: 31
# Iteration: 400 Average Training Loss: 147.298
# Average Validation Loss: 141.7730005640183
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 0 Average Training Loss: 143.786
# Average Validation Loss: 141.92581187895615
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 100 Average Training Loss: 147.520
# Average Validation Loss: 142.11612740398323
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 200 Average Training Loss: 146.736
# Average Validation Loss: 141.76121164586422
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 300 Average Training Loss: 147.953
# Average Validation Loss: 142.30353986085765
# ------------------------------------------------------------------------------------------------------
# Epoch: 32
# Iteration: 400 Average Training Loss: 147.252
# Average Validation Loss: 141.77316952447822
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 0 Average Training Loss: 143.653
# Average Validation Loss: 141.94700377526945
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 100 Average Training Loss: 147.529
# Average Validation Loss: 141.8620491863167
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 200 Average Training Loss: 147.104
# Average Validation Loss: 142.78352612126483
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 300 Average Training Loss: 148.341
# Average Validation Loss: 142.16952548061843
# ------------------------------------------------------------------------------------------------------
# Epoch: 33
# Iteration: 400 Average Training Loss: 147.341
# Average Validation Loss: 141.94306578253307
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 0 Average Training Loss: 145.484
# Average Validation Loss: 142.3546749588347
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 100 Average Training Loss: 147.228
# Average Validation Loss: 141.82129485415717
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 200 Average Training Loss: 146.894
# Average Validation Loss: 141.76500239685504
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 300 Average Training Loss: 148.113
# Average Validation Loss: 141.74698577658103
# ------------------------------------------------------------------------------------------------------
# Epoch: 34
# Iteration: 400 Average Training Loss: 147.478
# Average Validation Loss: 142.10563826735003
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 0 Average Training Loss: 143.322
# Average Validation Loss: 141.8876319384053
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 100 Average Training Loss: 147.325
# Average Validation Loss: 142.15263444663833
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 200 Average Training Loss: 147.072
# Average Validation Loss: 141.9224285487711
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 300 Average Training Loss: 147.803
# Average Validation Loss: 141.5081916307881
# ------------------------------------------------------------------------------------------------------
# Epoch: 35
# Iteration: 400 Average Training Loss: 147.437
# Average Validation Loss: 142.0808438489037
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 0 Average Training Loss: 142.786
# Average Validation Loss: 142.1272813560319
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 100 Average Training Loss: 147.247
# Average Validation Loss: 141.91003061559078
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 200 Average Training Loss: 146.857
# Average Validation Loss: 141.45370784119098
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 300 Average Training Loss: 147.844
# Average Validation Loss: 141.8496476890397
# ------------------------------------------------------------------------------------------------------
# Epoch: 36
# Iteration: 400 Average Training Loss: 147.129
# Average Validation Loss: 141.41728500032076
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 0 Average Training Loss: 142.424
# Average Validation Loss: 141.96392632922988
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 100 Average Training Loss: 147.233
# Average Validation Loss: 141.79208006475963
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 200 Average Training Loss: 146.919
# Average Validation Loss: 141.7321857535926
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 300 Average Training Loss: 147.845
# Average Validation Loss: 141.71119879284043
# ------------------------------------------------------------------------------------------------------
# Epoch: 37
# Iteration: 400 Average Training Loss: 147.036
# Average Validation Loss: 141.8090397076015
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 0 Average Training Loss: 144.798
# Average Validation Loss: 142.0189612172816
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 100 Average Training Loss: 146.772
# Average Validation Loss: 141.58919931676266
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 200 Average Training Loss: 146.825
# Average Validation Loss: 141.69287632851706
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 300 Average Training Loss: 148.336
# Average Validation Loss: 141.75121803005246
# ------------------------------------------------------------------------------------------------------
# Epoch: 38
# Iteration: 400 Average Training Loss: 146.742
# Average Validation Loss: 141.65217367575985
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 0 Average Training Loss: 146.174
# Average Validation Loss: 141.73025824553775
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 100 Average Training Loss: 147.370
# Average Validation Loss: 141.6283885649521
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 200 Average Training Loss: 146.750
# Average Validation Loss: 141.55372575077698
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 300 Average Training Loss: 147.349
# Average Validation Loss: 141.3466413734603
# ------------------------------------------------------------------------------------------------------
# Epoch: 39
# Iteration: 400 Average Training Loss: 146.553
# Average Validation Loss: 141.55952431337676
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 0 Average Training Loss: 143.801
# Average Validation Loss: 141.63617455698278
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 100 Average Training Loss: 147.080
# Average Validation Loss: 141.20576332259353
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 200 Average Training Loss: 146.378
# Average Validation Loss: 141.48149777154853
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 300 Average Training Loss: 147.644
# Average Validation Loss: 141.4647022999116
# ------------------------------------------------------------------------------------------------------
# Epoch: 40
# Iteration: 400 Average Training Loss: 147.098
# Average Validation Loss: 141.39475088746008
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 0 Average Training Loss: 143.092
# Average Validation Loss: 141.81102390706974
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 100 Average Training Loss: 147.147
# Average Validation Loss: 141.71392543820568
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 200 Average Training Loss: 146.171
# Average Validation Loss: 141.46030609799126
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 300 Average Training Loss: 147.753
# Average Validation Loss: 141.69930506796732
# ------------------------------------------------------------------------------------------------------
# Epoch: 41
# Iteration: 400 Average Training Loss: 146.683
# Average Validation Loss: 141.19627447197908
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 0 Average Training Loss: 142.719
# Average Validation Loss: 141.3404341648965
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 100 Average Training Loss: 147.088
# Average Validation Loss: 141.2496448154867
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 200 Average Training Loss: 146.588
# Average Validation Loss: 141.3401556084626
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 300 Average Training Loss: 147.583
# Average Validation Loss: 142.0017940771841
# ------------------------------------------------------------------------------------------------------
# Epoch: 42
# Iteration: 400 Average Training Loss: 146.707
# Average Validation Loss: 142.02211599976476
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 0 Average Training Loss: 144.686
# Average Validation Loss: 141.5671660708685
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 100 Average Training Loss: 147.019
# Average Validation Loss: 141.07334175945198
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 200 Average Training Loss: 146.238
# Average Validation Loss: 141.02772945209142
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 300 Average Training Loss: 147.135
# Average Validation Loss: 141.40866278209825
# ------------------------------------------------------------------------------------------------------
# Epoch: 43
# Iteration: 400 Average Training Loss: 146.865
# Average Validation Loss: 141.27073580331177
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 0 Average Training Loss: 144.157
# Average Validation Loss: 141.4510558191007
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 100 Average Training Loss: 146.794
# Average Validation Loss: 141.41508205441662
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 200 Average Training Loss: 146.156
# Average Validation Loss: 141.37180300524636
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 300 Average Training Loss: 147.340
# Average Validation Loss: 141.68228104862854
# ------------------------------------------------------------------------------------------------------
# Epoch: 44
# Iteration: 400 Average Training Loss: 146.776
# Average Validation Loss: 141.19636702711566
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 0 Average Training Loss: 143.205
# Average Validation Loss: 142.05300112536355
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 100 Average Training Loss: 146.961
# Average Validation Loss: 141.22993558340698
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 200 Average Training Loss: 146.309
# Average Validation Loss: 141.3365562049142
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 300 Average Training Loss: 147.482
# Average Validation Loss: 141.43311315383355
# ------------------------------------------------------------------------------------------------------
# Epoch: 45
# Iteration: 400 Average Training Loss: 146.459
# Average Validation Loss: 141.31076640108205
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 0 Average Training Loss: 143.502
# Average Validation Loss: 141.66713753581917
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 100 Average Training Loss: 146.535
# Average Validation Loss: 140.75136582868814
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 200 Average Training Loss: 146.001
# Average Validation Loss: 141.02652946527857
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 300 Average Training Loss: 147.137
# Average Validation Loss: 141.60435998178747
# ------------------------------------------------------------------------------------------------------
# Epoch: 46
# Iteration: 400 Average Training Loss: 146.035
# Average Validation Loss: 140.75781762338903
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 0 Average Training Loss: 144.601
# Average Validation Loss: 140.79090168528313
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 100 Average Training Loss: 146.918
# Average Validation Loss: 141.66632781759665
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 200 Average Training Loss: 146.381
# Average Validation Loss: 141.2415681268177
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 300 Average Training Loss: 147.492
# Average Validation Loss: 141.64420457826043
# ------------------------------------------------------------------------------------------------------
# Epoch: 47
# Iteration: 400 Average Training Loss: 146.291
# Average Validation Loss: 140.9808055571396
# ------------------------------------------------------------------------------------------------------
# Epoch: 48
# Iteration: 0 Average Training Loss: 143.885
# Average Validation Loss: 141.24747895846403
# ...
# Epoch: 186
# Iteration: 100 Average Training Loss: 144.152
# Average Validation Loss: 138.8946862882071
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 200 Average Training Loss: 144.115
# Average Validation Loss: 139.21618841686387
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 300 Average Training Loss: 144.671
# Average Validation Loss: 138.94488581079636
# ------------------------------------------------------------------------------------------------------
# Epoch: 186
# Iteration: 400 Average Training Loss: 144.671
# Average Validation Loss: 139.60787629733122
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 0 Average Training Loss: 141.426
# Average Validation Loss: 139.8830969594691
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 100 Average Training Loss: 144.622
# Average Validation Loss: 139.30568934531107
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 200 Average Training Loss: 144.087
# Average Validation Loss: 138.68591085837704
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 300 Average Training Loss: 145.336
# Average Validation Loss: 139.0272113215314
# ------------------------------------------------------------------------------------------------------
# Epoch: 187
# Iteration: 400 Average Training Loss: 144.297
# Average Validation Loss: 139.34028614350478
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 0 Average Training Loss: 139.988
# Average Validation Loss: 138.734031176045
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 100 Average Training Loss: 144.156
# Average Validation Loss: 138.72520747498004
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 200 Average Training Loss: 144.065
# Average Validation Loss: 139.12484618695112
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 300 Average Training Loss: 145.060
# Average Validation Loss: 138.9968885435675
# ------------------------------------------------------------------------------------------------------
# Epoch: 188
# Iteration: 400 Average Training Loss: 144.426
# Average Validation Loss: 139.0963474468593
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 0 Average Training Loss: 142.481
# Average Validation Loss: 139.96288004408788
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 100 Average Training Loss: 144.256
# Average Validation Loss: 138.93554899118243
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 200 Average Training Loss: 144.043
# Average Validation Loss: 139.10424994030137
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 300 Average Training Loss: 144.739
# Average Validation Loss: 138.45332291874573
# ------------------------------------------------------------------------------------------------------
# Epoch: 189
# Iteration: 400 Average Training Loss: 144.033
# Average Validation Loss: 138.88119529111543
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 0 Average Training Loss: 142.316
# Average Validation Loss: 138.7613904075901
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 100 Average Training Loss: 144.533
# Average Validation Loss: 139.00529513393874
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 200 Average Training Loss: 143.804
# Average Validation Loss: 138.60861295157105
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 300 Average Training Loss: 145.098
# Average Validation Loss: 139.14791602809933
# ------------------------------------------------------------------------------------------------------
# Epoch: 190
# Iteration: 400 Average Training Loss: 144.706
# Average Validation Loss: 139.51262046646897
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 0 Average Training Loss: 140.450
# Average Validation Loss: 139.66345203705947
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 100 Average Training Loss: 144.446
# Average Validation Loss: 138.6134366223412
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 200 Average Training Loss: 143.554
# Average Validation Loss: 138.50987510959598
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 300 Average Training Loss: 144.754
# Average Validation Loss: 139.41588943370067
# ------------------------------------------------------------------------------------------------------
# Epoch: 191
# Iteration: 400 Average Training Loss: 144.509
# Average Validation Loss: 139.0618009915317
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 0 Average Training Loss: 143.183
# Average Validation Loss: 139.53044317760606
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 100 Average Training Loss: 144.783
# Average Validation Loss: 139.0591129943402
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 200 Average Training Loss: 144.192
# Average Validation Loss: 139.10131045153543
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 300 Average Training Loss: 144.702
# Average Validation Loss: 138.86860779254107
# ------------------------------------------------------------------------------------------------------
# Epoch: 192
# Iteration: 400 Average Training Loss: 143.935
# Average Validation Loss: 139.14457323951441
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 0 Average Training Loss: 141.859
# Average Validation Loss: 139.2573366930885
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 100 Average Training Loss: 144.367
# Average Validation Loss: 139.02854295716668
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 200 Average Training Loss: 143.973
# Average Validation Loss: 139.2849564378279
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 300 Average Training Loss: 145.019
# Average Validation Loss: 139.01744736720175
# ------------------------------------------------------------------------------------------------------
# Epoch: 193
# Iteration: 400 Average Training Loss: 144.347
# Average Validation Loss: 139.1545837847856
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 0 Average Training Loss: 143.381
# Average Validation Loss: 139.40765380859375
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 100 Average Training Loss: 144.665
# Average Validation Loss: 139.05567564581432
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 200 Average Training Loss: 144.035
# Average Validation Loss: 138.79019142763457
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 300 Average Training Loss: 145.004
# Average Validation Loss: 138.89744824040545
# ------------------------------------------------------------------------------------------------------
# Epoch: 194
# Iteration: 400 Average Training Loss: 144.392
# Average Validation Loss: 139.1907705042484
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 0 Average Training Loss: 141.324
# Average Validation Loss: 139.19121623909388
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 100 Average Training Loss: 144.124
# Average Validation Loss: 138.86090867536782
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 200 Average Training Loss: 143.671
# Average Validation Loss: 138.89837401452726
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 300 Average Training Loss: 144.965
# Average Validation Loss: 139.28528544850593
# ------------------------------------------------------------------------------------------------------
# Epoch: 195
# Iteration: 400 Average Training Loss: 144.428
# Average Validation Loss: 138.91127649014885
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 0 Average Training Loss: 141.466
# Average Validation Loss: 139.68672169037978
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 100 Average Training Loss: 144.791
# Average Validation Loss: 138.9874630670478
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 200 Average Training Loss: 144.278
# Average Validation Loss: 138.92453893953865
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 300 Average Training Loss: 145.220
# Average Validation Loss: 139.07027028772953
# ------------------------------------------------------------------------------------------------------
# Epoch: 196
# Iteration: 400 Average Training Loss: 144.470
# Average Validation Loss: 139.17015487782277
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 0 Average Training Loss: 141.903
# Average Validation Loss: 139.03423170103645
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 100 Average Training Loss: 145.060
# Average Validation Loss: 138.7908671580962
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 200 Average Training Loss: 144.268
# Average Validation Loss: 138.28674628264713
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 300 Average Training Loss: 144.752
# Average Validation Loss: 138.8724375258397
# ------------------------------------------------------------------------------------------------------
# Epoch: 197
# Iteration: 400 Average Training Loss: 144.790
# Average Validation Loss: 139.2604497088133
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 0 Average Training Loss: 141.630
# Average Validation Loss: 139.3821190604328
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 100 Average Training Loss: 144.883
# Average Validation Loss: 138.88365941848198
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 200 Average Training Loss: 144.038
# Average Validation Loss: 138.87951292608776
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 300 Average Training Loss: 145.010
# Average Validation Loss: 139.1376792740648
# ------------------------------------------------------------------------------------------------------
# Epoch: 198
# Iteration: 400 Average Training Loss: 144.632
# Average Validation Loss: 139.37394202016566
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 0 Average Training Loss: 144.882
# Average Validation Loss: 140.2766940819956
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 100 Average Training Loss: 145.635
# Average Validation Loss: 138.8732825508953
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 200 Average Training Loss: 144.541
# Average Validation Loss: 139.40989829850022
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 300 Average Training Loss: 145.065
# Average Validation Loss: 138.76698525978702
# ------------------------------------------------------------------------------------------------------
# Epoch: 199
# Iteration: 400 Average Training Loss: 144.590
# Average Validation Loss: 138.86801114047532
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 0 Average Training Loss: 145.408
# Average Validation Loss: 139.6464136499558
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 100 Average Training Loss: 144.674
# Average Validation Loss: 139.11949224541658
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 200 Average Training Loss: 144.360
# Average Validation Loss: 138.73692087883498
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 300 Average Training Loss: 145.227
# Average Validation Loss: 138.86384504554917
# ------------------------------------------------------------------------------------------------------
# Epoch: 200
# Iteration: 400 Average Training Loss: 144.635
# Average Validation Loss: 138.83274239867274
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 0 Average Training Loss: 144.638
# Average Validation Loss: 138.91848353921932
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 100 Average Training Loss: 144.547
# Average Validation Loss: 138.9040801333685
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 200 Average Training Loss: 144.123
# Average Validation Loss: 139.34465249611515
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 300 Average Training Loss: 144.740
# Average Validation Loss: 138.60558770172787
# ------------------------------------------------------------------------------------------------------
# Epoch: 201
# Iteration: 400 Average Training Loss: 144.302
# Average Validation Loss: 138.61170057310676

# %%
# Closing the Writer and saving the model. Saving the model is not enough, we also need to save the model class as well
writer.close()
PATH = '/content/drive/My Drive/Colab Notebooks/VAE/MNIST_VAE_NN_BCE_KL/BCE_KL_NN/LD2/saved_model'
torch.save(net.state_dict(), PATH)
